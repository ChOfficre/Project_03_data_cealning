# %% [markdown]
# # Project 3: Data Cleaning - Tidy up messy Datasets (Movies Dataset)# Read and Cleaning data from CSV file

# %%
import pandas as pd
import numpy as np
import json
pd.options.display.max_columns = 30

# %%
df = pd.read_csv("movies_metadata.csv")
df
# Out:
# C:\Users\pytho\AppData\Local\Temp\ipykernel_4368\1131639009.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("movies_metadata.csv")
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %%
df.drop(["adult", "imdb_id", "original_title", "video", "homepage"], axis=1, inplace=True)
df.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                NaN  65000000
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                NaN  16000000
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                                             overview popularity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  4494 non-null   object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   id                     45466 non-null  object
#  4   original_language      45455 non-null  object
#  5   overview               44512 non-null  object
#  6   popularity             45461 non-null  object
#  7   poster_path            45080 non-null  object
#  8   production_companies   45463 non-null  object
#  9   production_countries   45463 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45460 non-null  float64
#  12  runtime                45203 non-null  float64
#  13  spoken_languages       45460 non-null  object
# ...

# %%
import ast

# %%
json_col = ["belongs_to_collection", "genres", "production_companies", "production_countries", "spoken_languages"]

# %% [markdown]
# Option 1

# %% [markdown]
# create a example of str dict '{"abc": int or str}' and convert it to a dict

# %%
json1 = '{"dog": 3,"cat": 5}'

# %%
json.loads(json1)
# Out:
# {'dog': 3, 'cat': 5}

# %%
df.genres[0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.genres.apply(lambda x: json.loads(x.replace("'", '"')))[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %% [markdown]
# Option 2

# %% [markdown]
#  Using AST module

# %%
ast.literal_eval(json1)
# Out:
# {'dog': 3, 'cat': 5}

# %%
df.genres.apply(ast.literal_eval)[0]
# Out:
# [{'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 10751, 'name': 'Family'}]

# %%
df_genres = df.genres.apply(ast.literal_eval)

# %% [markdown]
# get an errors because mixing data in variables

# %%
# df.loc[:, json_col].apply(ast.literal_eval, axis=0)

# %%
# ast.literal_eval(0)

# %% [markdown]
# check is element is str or not for belong_to_collections[0]

# %%
df.belongs_to_collection.apply(lambda x: isinstance(x, str))
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# Name: belongs_to_collection, Length: 45466, dtype: bool

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.spoken_languages
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.spoken_languages.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)
# Out:
# 0                 [{'iso_639_1': 'en', 'name': 'English'}]
# 1        [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2                 [{'iso_639_1': 'en', 'name': 'English'}]
# 3                 [{'iso_639_1': 'en', 'name': 'English'}]
# 4                 [{'iso_639_1': 'en', 'name': 'English'}]
#                                ...
# 45461               [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 45462                    [{'iso_639_1': 'tl', 'name': ''}]
# 45463             [{'iso_639_1': 'en', 'name': 'English'}]
# 45464                                                   []
# 45465             [{'iso_639_1': 'en', 'name': 'English'}]
# Name: spoken_languages, Length: 45466, dtype: object

# %%
df.production_companies = df.production_companies.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df.production_countries = df.production_countries.apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else np.nan)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# ...

# %% [markdown]
# ## How to flatten nested Columns

# %% [markdown]
# 1. __Extract__ only the __collection name__ from the column "belongs_to_collection" and __overwrite__ "belongs_to_collection". <br> For example: The value in the first row (Toy Story) should be 'Toy Story Collection'.

# %%
df.belongs_to_collection[0]
# Out:
# {'id': 10194,
#  'name': 'Toy Story Collection',
#  'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg',
#  'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}

# %%
df.belongs_to_collection = df.belongs_to_collection.apply(lambda x: x["name"] if isinstance(x, dict) else np.nan)

# %%
df.belongs_to_collection.value_counts(dropna=False).head(20)
# Out:
# belongs_to_collection
# NaN                                       40975
# The Bowery Boys                              29
# Totò Collection                              27
# James Bond Collection                        26
# Zatôichi: The Blind Swordsman                26
# The Carry On Collection                      25
# Pokémon Collection                           22
# Charlie Chan (Sidney Toler) Collection       21
# Godzilla (Showa) Collection                  16
# Charlie Chan (Warner Oland) Collection       15
# Dragon Ball Z (Movie) Collection             15
# Uuno Turhapuro                               15
# Monster High Collection                      14
# The Land Before Time Collection              14
# George Carlin Comedy Collection              13
# Sharpe Collection                            13
# Friday the 13th Collection                   12
# The Amityville Horror Collection             12
# Johan Falk GSI Collection                    12
# ...

# %% [markdown]
# 2. __Extract__ all __genre names__ from the column "genres" and __overwrite__ "genres". If a movie has more than one genre, __seperate genres by a pipe__ "|".<br>
# For example: The value in the first row (Toy Story) should be 'Animation|Comedy|Family'.

# %%
df.genres[0]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
df.genres = df.genres.apply(lambda x: "|".join(i["name"] for i in x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.genres = df.genres.apply(lambda x: "|".join(i["name"] for i in x))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)   4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)   4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...
